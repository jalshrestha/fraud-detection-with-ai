# %% [markdown]
# # Hybrid GNN-LLM Fraud Detection Pipeline
#
# End-to-end runner that calls each pipeline step in order. Each step is
# implemented as a standalone script under `scripts/`. This notebook is
# a convenience wrapper for interactive exploration and debugging.
#
# Set `ETHERSCAN_API_KEY` in your environment before running step 3.

# %% [markdown]
# ## Setup

# %%
import os, sys
from pathlib import Path

ROOT = Path.cwd()
if (ROOT / 'scripts').exists():
    CODE_DIR = ROOT
else:
    CODE_DIR = ROOT.parent
sys.path.insert(0, str(CODE_DIR))
os.chdir(CODE_DIR)
print('Working directory:', os.getcwd())

# %% [markdown]
# ## Step 1: load transactions and discover common contracts

# %%
# !python scripts/01_fetch_transactions.py --restrict-to-seeds

# %% [markdown]
# ## Step 2: download Forta fraud labels

# %%
# !python scripts/02_fetch_labels.py

# %% [markdown]
# ## Step 3: fetch verified Solidity source from Etherscan

# %%
# !python scripts/03_fetch_sources.py

# %% [markdown]
# ## Step 4: build the unified node and edge tables and the PyG graph

# %%
# !python scripts/04_build_dataset.py

# %% [markdown]
# ## Step 5: train the fusion classifier

# %%
# !python scripts/05_train.py

# %% [markdown]
# ## Step 6: evaluate on the held-out test split

# %%
# !python scripts/06_evaluate.py

# %% [markdown]
# ## Step 7: ablation study (GNN-only and LLM-only)

# %%
# !python scripts/07_ablation.py

# %% [markdown]
# ## Step 8: render dataset and graph figures

# %%
# !python scripts/08_visualize.py
